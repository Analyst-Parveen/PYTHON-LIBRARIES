# %%
import matplotlib.pyplot as plt
y= [98,67,85,34,40]
x=['part1','part2','part3','part4','part5']
rang=['red','blue','orange','purple','pink']
plt.bar(x,y,color=rang,edgecolor="black")
plt.xlabel("parts of harry potter",fontsize=17)
plt.ylabel('popularty',)
plt.title('pupularty of differnt part of harry potter',fontsize=17)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data =pd.read_excel("D:/expense3.xlsx")
# data['Payment Mode'].fillna(method="bfill")
data['Payment Mode']=data['Payment Mode'].ffill()
# print(data)

# data['Payment Mode']=data['Payment Mode'].replace(np.nan,'UPI')
# print(data)
df=pd.DataFrame(data)
# print(df)

# print(df)
# plt.bar(df['Payment Mode'],df['Amount'])

group_by=df.groupby('Payment Mode')['Amount'].sum()
print(group_by)
colors=['blue','red','orange']
plt.bar(group_by.index,group_by.values,color=colors,edgecolor="black")
plt.xlabel('types of payment mode',fontsize=15)
plt.ylabel('total of amount',fontsize=15,color='green')
plt.title('total payment against payment mode')
plt.show()

# plt.show()
# print(df)
# print(df.columns)
print(df['Amount'].sum())
# Out:
# Payment Mode
# Card      900
# Cash     5637
# UPI     23612
# Name: Amount, dtype: int64
# 30149

# %%
# line plot matlib: use when we want to see frequency or flucations in our data.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x=['day1','day2','day3','day4','day5','day6','day7']
y=[300,420,250,270,500,430,220]
y1=[500,450,300,250,230,400,320]
plt.plot(x,y, marker='D',linewidth=2,label='week1',color='green',ls=':',alpha=0.5)
# plt.show()
plt.plot(x,y1,marker='*',label='week2',linewidth=2,color='orange',linestyle='-.')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_excel("D:/expense3.xlsx")
df=pd.DataFrame(data)
df
# print(data)
# plt.plot(df['Date'],df['Amount'], marker='D',linewidth=2,label='week1',color='green',ls=':',alpha=0.5)
# --------------or---------------------
# group_by=data.groupby('Category').agg({'Amount':'sum'})
# -----------------------------or---------------------------
group_by=data.groupby('Category')['Amount'].sum()

print(group_by)
plt.plot(group_by.index,group_by.values,marker='D',linewidth=2,label='week1',color='green',ls=':',alpha=0.5)
plt.show()
# Out:
# Category
# Bills         18724
# Clothes        2890
# Essentials     4485
# Food           3022
# Grocery        1028
# Name: Amount, dtype: int64

# %%
#  scatter plot where you want to show high frequency b/w no-no --or---int-int.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
x=np.random.randint(10,50,25)
y=np.random.randint(10,50,25)
rang=np.random.randint(50,90,25)
plt.scatter(x,y,marker='*',c=rang,cmap='hot',s=40)
# plt.show()
plt.colorbar()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_excel("D:/scatter-dataset.xlsx")
df=pd.DataFrame(data)
plt.scatter(df['QUANTITYORDERED'],df['PRICEEACH'],marker='*',cmap='Pastel2',s=40,c=df['QUANTITYORDERED'])
# print(data)
plt.colorbar()
plt.show()

# %%
#  pie chart- circular chart which shows percentage value of overall chart-----

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
brands=['oneplus','apple','samsung','vivo','oppo','redime']
popularty=[11,35,11,30,3,10]
c=['red','green','orange','blue','pink','purple']
explode=[0,0.05,0,0,0,0]
plt.pie(popularty,labels=brands,colors=c,explode=explode,shadow=True,autopct='%.1f',startangle=30)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_excel("D:/expense3.xlsx")
df=pd.DataFrame(data)
df['Payment Mode']=df['Payment Mode'].bfill()
# print(df)
group_by=df.groupby('Payment Mode')['Amount'].sum()
print(group_by)
plt.pie(group_by.values,labels=group_by.index,shadow=True,autopct='%.1f',startangle=30)
plt.show
# Out:
# Payment Mode
# Card      780
# Cash     4637
# UPI     24732
# Name: Amount, dtype: int64
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# BOX-PLOT:=> its basically use for statically analysis use where to check the range frequency is going high etc.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data1=[1,3,4,7,5,2,8,9,24]
data2=[1,3,4,7,12,11,2,8,9,45]
final_data=[data1,data2]
plt.boxplot(final_data)
# plt.boxplot(data)
# plt.boxplot(data2)
plt.show
print(np.median(data))
# Out:
# 5.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_excel("D:/scatter-dataset.xlsx")
df=pd.DataFrame(data)
# print(df)
plt.boxplot(df['QUANTITYORDERED'])
plt.show()

# %%
# HISTOGRAM-PLOT:=> use to find the frequency of a value in a data.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=[30,40,68,27,47,59,47,88,44,23,44,66,66,33,51,2,5,50]
plt.hist(data,bins=5,edgecolor='black',color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_excel("D:/scatter-dataset.xlsx")
df=pd.DataFrame(data)
plt.hist(df['PRICEEACH'],edgecolor='red',color='yellow',bins=5,align='mid')
plt.show()
print(df)
# Out:
#     QUANTITYORDERED  PRICEEACH
# 0                30         95
# 1                34         81
# 2                41         94
# 3                45         83
# 4               200        100
# 5                36         96
# 6                29         86
# 7                48        100
# 8                22         98
# 9                41         13
# 10               37         34
# 11               23         62
# 12               28         36
# 13               34         23
# 14               45         43
# 15               36         11
# 16               23         32
# 17               41         56
# 18               46         79
# 19               42         90
# 20               41         89
# 21               20         72
# 22               21         63

# %%
#  VIOLIN PLOT:=>To find in which range values are more or less and yo cehck the values from mean values.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=[20,30,40,50,30,40,40,40,40,70,80,40,20]
df=pd.DataFrame(data)
# print(df)
plt.violinplot(df,showmedians=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_excel("D:/scatter-dataset.xlsx")
df=pd.DataFrame(data)
# print(data)
plt.violinplot(data['QUANTITYORDERED'],showmedians=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#  STEM-PLOT:=> A stem plot displays discrete data points as vertical stems with horizontal lines (leaves) extending from them, effectively
#  showing the distribution of the data.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=[10,40,20,20,40,20,40,60,70,50,35,40]
c=['red','black']
df=pd.DataFrame(data)
plt.stem(df,linefmt='r--',markerfmt='y*-')     # note-'*'- its gives only star at points,where '*-' its gives line passing thorugh stars,'y' gives color.
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_excel("D:/scatter-dataset.xlsx")
df=pd.DataFrame(data)
print(df)
plt.stem(df['QUANTITYORDERED'],linefmt='y--',markerfmt='b*-',orientation='vertical')
# Out:
#     QUANTITYORDERED  PRICEEACH
# 0                30         95
# 1                34         81
# 2                41         94
# 3                45         83
# 4               200        100
# 5                36         96
# 6                29         86
# 7                48        100
# 8                22         98
# 9                41         13
# 10               37         34
# 11               23         62
# 12               28         36
# 13               34         23
# 14               45         43
# 15               36         11
# 16               23         32
# 17               41         56
# 18               46         79
# 19               42         90
# 20               41         89
# 21               20         72
# 22               21         63
# <StemContainer object of 3 artists>

# %%
#  STACK-PLOT:=> its use to cehck which month or week or etc population or etc is high.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
day=[1,2,3,4,5,6,7]
week1=[5,10,30,20,35,60,80]
week2=[10,20,30,25,40,50,90]
week3=[8,30,50,60,70,90,100]
c=['orange','yellow','green']
lb=['week1','week2','week3']
plt.stackplot(day,week1,week2,week3,baseline='sym',colors=c,labels=lb)
plt.legend()
plt.show()

# %%
# STEP-PLOT:=> To check the steps how day is flowing day by day or in other condition.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
x=['day1','day2','day3','day4','day5']
y=[30,40,25,30,40]
plt.step(x,y,where='mid',marker="d",color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_excel("D:/expense3.xlsx")
df=pd.DataFrame(data)
# print(df)
group_by=df.groupby('Category')['Amount'].sum()
print(group_by)
plt.step(group_by.index,group_by.values,where='mid',marker='*',color='black')
# Out:
# Category
# Bills         18724
# Clothes        2890
# Essentials     4485
# Food           3022
# Grocery        1028
# Name: Amount, dtype: int64

# %%
#  legends:=> placing legends at a particular place and with a good dimension.

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
x=[1,2,3,4,5]
y=[45,67,33,67,12]
y1=[41,60,13,66,13]
y2=[4,10,13,26,23]
y3=[21,30,19,26,33]
plt.figure(figsize=[5,5])
plt.plot(x,y,label='male')
plt.plot(x,y1,label='female')
plt.plot(x,y2)
plt.plot(x,y3)
# plt.legend(loc=0)
plt.legend(['a1','a2','a3','a4'],ncols=2,labelspacing=2,bbox_to_anchor=(0.2,1),loc='best')
plt.show()

# %%
#  SUB-PLOT= use to create multiple plot in a single plot.

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 

x=[1,2,3,4,5,6]
y=[45,34,56,23,45,22]
y1=[22,35,45,65,23,11]
plt.subplot(1,3,1)
plt.title('height')
plt.plot(x,y)
plt.subplot(1,3,2)
plt.title('lenght')
plt.plot(x,y1)
plt.subplot(1,3,3)
plt.title('timepaas')
plt.plot(y,y1)
plt.suptitle('HEIGHT LENGTH & TIMEPAAS')

#  SAVE GRAPH:=> to save figure use plt.savefig().
plt.savefig('sub_plot.png',facecolor='yellow')
plt.show()

# %%
import pandas as pd
import mysql.connector
import os

# List of CSV files and their corresponding table names
csv_files = [
 ('customers.csv', 'customers'),
    ('orders.csv', 'orders'),
    ('sellers.csv', 'sellers'),
    ('products.csv', 'products'),
    ('geolocation.csv', 'geolocation'),
    ('payments.csv', 'payments'),
    ('order_items.csv','order_item')  # Added payments.csv for specific handling
]

# Connect to the MySQL database
conn = mysql.connector.connect(
   host='localhost',
    user='root',
    password='parveen1182002',
    database='python_sql_project'
)
cursor = conn.cursor()

# Folder containing the CSV files
folder_path = 'D:/python_sql_project_dataset'

def get_sql_type(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'

for csv_file, table_name in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Replace NaN with None to handle SQL NULL
    df = df.where(pd.notnull(df), None)
    
    # Debugging: Check for NaN values
    print(f"Processing {csv_file}")
    print(f"NaN values before replacement:\n{df.isnull().sum()}\n")

    # Clean column names
    df.columns = [col.replace(' ', '_').replace('-', '_').replace('.', '_') for col in df.columns]

    # Generate the CREATE TABLE statement with appropriate data types
    columns = ', '.join([f'`{col}` {get_sql_type(df[col].dtype)}' for col in df.columns])
    create_table_query = f'CREATE TABLE IF NOT EXISTS `{table_name}` ({columns})'
    cursor.execute(create_table_query)

    # Insert DataFrame data into the MySQL table
    for _, row in df.iterrows():
        # Convert row to tuple and handle NaN/None explicitly
        values = tuple(None if pd.isna(x) else x for x in row)
        sql = f"INSERT INTO `{table_name}` ({', '.join(['`' + col + '`' for col in df.columns])}) VALUES ({', '.join(['%s'] * len(row))})"
        cursor.execute(sql, values)

    # Commit the transaction for the current CSV file
    conn.commit()

# Close the connection
conn.close()
